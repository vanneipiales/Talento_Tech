# %%
class CalculadoraSencilla:
  def __init__(self, numero_1, numero_2):
    self.numero_1 = numero_1
    self.numero_2 = numero_2

  def suma(self):
    return self.numero_1 + self.numero_2

  def resta(self):
    return self.numero_1 - self.numero_2

  def multiplicacion(self):
    return self.numero_1 * self.numero_2

  def division(self):
    if self.numero_2 != 0:
      return self.numero_1 / self.numero_2
    return "No se puede dividir por cero"



#Menu Principal
while True:
    print("\n MENÚ DE CALCULADORA")
    print("1) Suma")
    print("2) Resta")
    print("3) Multiplicación")
    print("4) División")
    print("5) Salir")

    opcion = input("Ingrese una opción (1-5): ")

    if opcion == '5':
        print(" ¡Gracias por usar esta calculadora!")
        break

    if opcion not in ['1', '2', '3', '4']:
        print("¡Error! Opción no válida")
        continue

    try:
        numero_1 = float(input("Ingrese el primer número: "))
        numero_2 = float(input("Ingrese el segundo número: "))

        #Crear objeto de la clase
        c = CalculadoraSencilla(numero_1, numero_2)

        if opcion == '1':
            resultado = c.suma()
        elif opcion == '2':
            resultado = c.resta()
        elif opcion == '3':
            resultado = c.multiplicacion()
        elif opcion == '4':
            resultado = c.division()

        print(f"\nEl resultado es: {resultado}")

    except ValueError:
        print("¡Error! Ingrese números válidos.")
# Out:
#  MENÚ DE CALCULADORA
# 1) Suma
# 2) Resta
# 3) Multiplicación
# 4) División
# 5) Salir
# Ingrese una opción (1-5): 4
# Ingrese el primer número: 657
# Ingrese el segundo número: 98
#
# El resultado es: 6.704081632653061
#
#  MENÚ DE CALCULADORA
# 1) Suma
# 2) Resta
# 3) Multiplicación
# 4) División
# 5) Salir
# Ingrese una opción (1-5): 5
#  ¡Gracias por usar esta calculadora!

# %%
import math

class CalculadoraCompleja:
  def __init__(self, numero_1, numero_2):
    self.numero_1 = numero_1
    self.numero_2 = numero_2

  def suma(self):
    return self.numero_1 + self.numero_2

  def resta(self):
    return self.numero_1 - self.numero_2

  def multiplicacion(self):
    return self.numero_1 * self.numero_2

  def division(self):
    if self.numero_2 != 0:
      return self.numero_1 / self.numero_2
    return "No se puede dividir por cero"

  def raiz_cuadrada(self):
    if self.numero_1 >= 0:
      return math.sqrt(self.numero_1)
    else:
      return "No se puede calcular la raíz cuadrada de un número negativo"

  def raiz_cubica(self):
    return math.cbrt(self.numero_1)

  def potenciacion(self):
    return self.numero_1 ** self.numero_2

  def logaritmo(self):
    if self.numero_1 > 0:
      return math.log10(self.numero_1)
    else:
      return "No se puede calcular el logaritmo de un número negativo o cero"

  def seno(self):
    return math.sin(self.numero_1)

  def coseno(self):
    return math.cos(self.numero_1)

  def tangente(self):
    return math.tan(self.numero_1)


#Menu Principal
while True:
    print("\n MENÚ DE CALCULADORA")
    print("1) Suma")
    print("2) Resta")
    print("3) Multiplicación")
    print("4) División")
    print("5) Raíz Cuadrada")
    print("6) Raíz Cúbica")
    print("7) Potenciación")
    print("8) Logaritmo")
    print("9) Seno")
    print("10) Coseno")
    print("11) Tangente")
    print("12) Salir")

    opcion = input("Ingrese una opción (1-12): ")

    if opcion == '12':
        print("¡Gracias por usar esta calculadora!")
        break

    try:
        num1 = float(input("Ingrese el primer número: "))

        # Solo pedir segundo número si la operación lo requiere
        if opcion in ['1', '2', '3', '4', '7']:
            num2 = float(input("Ingrese el segundo número: "))
        else:
            num2 = 0  # Valor por defecto no usado en estas operaciones

        #Crear objeto de la clase
        c = CalculadoraCompleja(numero_1, numero_2)

        if opcion == '1':
            resultado = c.suma()
        elif opcion == '2':
            resultado = c.resta()
        elif opcion == '3':
            resultado = c.multiplicacion()
        elif opcion == '4':
            resultado = c.division()
        elif opcion == '5':
            resultado = c.raiz_cuadrada()
        elif opcion == '6':
            resultado = c.raiz_cubica()
        elif opcion == '7':
            resultado = c.potenciacion()
        elif opcion == '8':
            resultado = c.logaritmo()
        elif opcion == '9':
            resultado = c.seno()
        elif opcion == '10':
            resultado = c.coseno()
        elif opcion == '11':
            resultado = c.tangente()

        print(f"\nEl resultado es: {resultado}")

    except ValueError:
        print("¡Error! Ingrese números válidos.")
# Out:
#  MENÚ DE CALCULADORA
# 1) Suma
# 2) Resta
# 3) Multiplicación
# 4) División
# 5) Raíz Cuadrada
# 6) Raíz Cúbica
# 7) Potenciación
# 8) Logaritmo
# 9) Seno
# 10) Coseno
# 11) Tangente
# 12) Salir
# Ingrese una opción (1-12): 12
# ¡Gracias por usar esta calculadora!
