# %%
import pandas as pd

#Create a dataset
# Let'sbuild the values lists
value_n_list = ['Andres', 'Phillip', 'John']
print (value_n_list)

value_w_list =[50,      78,     91.5]#[kg]
value_h_list = [1.76,  1.87,    1.69 ]#[m]
#value_bmi_list will be calculated: bmi =w/(h^2)
#value_bmi_list =[25, 25, 25] #init values [kg/m2]

#Let's  use a dictoniary ({key:value})
#with the format {"str":list}
data_dict= {"name":value_n_list,
            "weight":value_w_list,
            "height":value_h_list}#,
            #"BMI": value_bmi_list

print (data_dict)

#Turn a dictionary into a dataframe
df = pd.DataFrame(data_dict)
print (df)
# Call a variable
df
# Out:
# ['Andres', 'Phillip', 'John']
# {'name': ['Andres', 'Phillip', 'John'], 'weight': [50, 78, 91.5], 'height': [1.76, 1.87, 1.69]}
#       name  weight  height
# 0   Andres    50.0    1.76
# 1  Phillip    78.0    1.87
# 2     John    91.5    1.69
#       name  weight  height
# 0   Andres    50.0    1.76
# 1  Phillip    78.0    1.87
# 2     John    91.5    1.69

# %%
#Import libraries
import pandas as pd

#Create a dataset
# Let'sbuild the values lists
value_n_list = ['Andres', 'Phillip', 'John', 'Sofia', 'Valentina', 'Alejandra', 'Nicolas', 'Gabriel', 'Diana', 'Elizabeth']
print (value_n_list)

value_w_list =[50,      78,     91.5,      45,      60,      78.5,     70.5,      60,    65.5,     78 ]#[kg]
value_h_list =[1.76,   1.87,    1.69,     1.56,    1.65,     1.71,     1.75,     1.67,   1.73,     75 ]#[m]
#value_bmi_list will be calculated: bmi =w/(h^2)
#value_bmi_list =[25, 25, 25] #init values [kg/m2]

#Let's  use a dictoniary ({key:value})
#with the format {"str":list}
data_dict= {"name":value_n_list,
            "weight":value_w_list,
            "height":value_h_list}#,
            #"BMI": value_bmi_list}

print (data_dict)

#Turn a dictionary into a dataframe
df = pd.DataFrame(data_dict)
print (df)

# Call a variable
df

#prompt: Con DataFrame df: add another colum
df['bmi'] =df['weight']/(df['height']**2)
df

def classify_bmi(bmi):
  if bmi < 18.5:
    return 'Underweight'
  elif bmi >= 18.5 and bmi < 25:
    return 'Normal'
  elif bmi >= 25 and bmi <= 29.9:
    return 'Overweight'
  else:
    return 'Obesity'

df['classification'] = df['bmi'].apply(classify_bmi)
df
# Out:
# ['Andres', 'Phillip', 'John', 'Sofia', 'Valentina', 'Alejandra', 'Nicolas', 'Gabriel', 'Diana', 'Elizabeth']
# {'name': ['Andres', 'Phillip', 'John', 'Sofia', 'Valentina', 'Alejandra', 'Nicolas', 'Gabriel', 'Diana', 'Elizabeth'], 'weight': [50, 78, 91.5, 45, 60, 78.5, 70.5, 60, 65.5, 78], 'height': [1.76, 1.87, 1.69, 1.56, 1.65, 1.71, 1.75, 1.67, 1.73, 75]}
#         name  weight  height
# 0     Andres    50.0    1.76
# 1    Phillip    78.0    1.87
# 2       John    91.5    1.69
# 3      Sofia    45.0    1.56
# 4  Valentina    60.0    1.65
# 5  Alejandra    78.5    1.71
# 6    Nicolas    70.5    1.75
# 7    Gabriel    60.0    1.67
# 8      Diana    65.5    1.73
# 9  Elizabeth    78.0   75.00
#         name  weight  height        bmi classification
# 0     Andres    50.0    1.76  16.141529    Underweight
# 1    Phillip    78.0    1.87  22.305471         Normal
# 2       John    91.5    1.69  32.036693        Obesity
# 3      Sofia    45.0    1.56  18.491124    Underweight
# 4  Valentina    60.0    1.65  22.038567         Normal
# 5  Alejandra    78.5    1.71  26.845867     Overweight
# 6    Nicolas    70.5    1.75  23.020408         Normal
# 7    Gabriel    60.0    1.67  21.513859         Normal
# 8      Diana    65.5    1.73  21.885128         Normal
# 9  Elizabeth    78.0   75.00   0.013867    Underweight
